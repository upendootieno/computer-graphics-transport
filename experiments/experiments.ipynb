# %%
import xml.etree.ElementTree as ET
tree = ET.parse('maps/the_shoe.osm')
root = tree.getroot()

# %%
for child in root:
    print(child.tag) # 1.Node, 2.Way -> Open, Close, Area, 3.Relation

    if child.tag == "way":
        print(child.attrib)
# Out:
# bounds
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# ...
